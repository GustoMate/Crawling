# %% [markdown]
# # 레시피 url 및 조리 시간 크롤링

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import re
import pandas as pd

# %%
# 드라이버 초기화
driver = webdriver.Chrome()

# %%
# url 설정
# difficulty = 10 : 초보, 20 : 보통
# 페이지: 60, 페이지: 46
beginner_url = "https://www.menupan.com/Cook/RecipeRe.asp?difficulty=10&page="
intermediate_url = "https://www.menupan.com/Cook/RecipeRe.asp?difficulty=20&page="

# %%
# 레시피 url 저장할 리스트
recipe_urls = []
# 요리시간 저장할 리스트
coocking_times = []

for page_num in range(1, 61):
    url = f"{beginner_url}{page_num}"
    driver.get(url)
    time.sleep(1)

    # 레시피 url 저장
    # 해당 페이지의 레시피 ID가져오기
    recipe_IDs = driver.find_elements(By.CSS_SELECTOR, "span.link a[href*='goRecipeView']")

    # 모든 요소를 순회하면서 데이터 추출
    for ID in recipe_IDs:
        recipe_ID = ID.get_attribute('href').split('(')[1].split(')')[0]
        recipe_urls.append(f"https://www.menupan.com/Cook/RecipeView.asp?cookid={recipe_ID}")

    # 요리시간 저장
    time_elements = driver.find_elements(By.XPATH, "//td[contains(text(), '조리시간')]")
    for element in time_elements:

        time_info = element.text.split('조리시간:')[1].split(' ')[0].strip()
        if (time_info == ''):  # '조리시간'이 없는 경우
            coocking_times.append('N/A')
        elif (time_info[-1] == '분'):
            coocking_times.append(time_info.split('분')[0])
        elif (time_info[-1].isdigit() == True):
            coocking_times.append(time_info)
        else:
            coocking_times.append(str(int(time_info.split('시')[0])*60))




# url이랑 조리시간 함께 저장
recipe_info = pd.DataFrame({
    'url': recipe_urls, 
    'cooking_time': coocking_times
})

# CSV 파일로 저장
recipe_info.to_csv('recipe_info_beginner.csv', index=False, encoding='utf-8-sig')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[139], line 9
#       7 url = f"{beginner_url}{page_num}"
#       8 driver.get(url)
# ----> 9 time.sleep(1)
#      11 # 레시피 url 저장
#      12 # 해당 페이지의 레시피 ID가져오기
#      13 recipe_IDs = driver.find_elements(By.CSS_SELECTOR, "span.link a[href*='goRecipeView']")
#
# KeyboardInterrupt:

# %%
# 레시피 url 저장할 리스트
recipe_urls = []
# 요리시간 저장할 리스트
coocking_times = []
for page_num in range(1, 47):
    url = f"{intermediate_url}{page_num}"
    driver.get(url)
    time.sleep(1)

    # 레시피 url 저장
    # 해당 페이지의 레시피 ID가져오기
    recipe_IDs = driver.find_elements(By.CSS_SELECTOR, "span.link a[href*='goRecipeView']")

    # 모든 요소를 순회하면서 데이터 추출
    for ID in recipe_IDs:
        recipe_ID = ID.get_attribute('href').split('(')[1].split(')')[0]
        recipe_urls.append(f"https://www.menupan.com/Cook/RecipeView.asp?cookid={recipe_ID}")

    # 요리시간 저장
    time_elements = driver.find_elements(By.XPATH, "//td[contains(text(), '조리시간')]")

    for element in time_elements:

        time_info = element.text.split('조리시간:')[1].split(' ')[0].strip()
        if (time_info == ''):  # '조리시간'이 없는 경우
            coocking_times.append('N/A')
        elif (time_info[-1] == '분'):
            coocking_times.append(time_info.split('분')[0])
        elif (time_info[-1].isdigit() == True):
            coocking_times.append(time_info)
        else:
            coocking_times.append(str(int(time_info.split('시')[0])*60))


# url이랑 조리시간 함께 저장
recipe_info = pd.DataFrame({
    'url': recipe_urls, 
    'cooking_time': coocking_times
})

# CSV 파일로 저장
recipe_info.to_csv('recipe_info_intermediate.csv', index=False, encoding='utf-8-sig')

# %% [markdown]
# # 위에 레시피 url을 통해서 레시피 정보 크롤링

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
import requests
import os

# %%
beginner_df = pd.read_csv('recipe_info_beginner.csv')
intermediate_df = pd.read_csv('recipe_info_intermediate.csv')
base_url = "https://www.menupan.com"
beginner_directory = 'beginner_img'
intermediate_directory = 'intermediate_img'

if not os.path.exists(beginner_directory):
    os.makedirs(beginner_directory)

if not os.path.exists(intermediate_directory):
    os.makedirs(intermediate_directory)

# %%
recipe_urls = beginner_df['url'].tolist()
data = []
cooking_time_counter = 0


for url in recipe_urls:
    driver.get(url)
    time.sleep(1)
    # 메뉴 이름 가져오기 (string)
    menu_name = driver.find_element(By.CLASS_NAME, 'wrap_top').find_element(By.TAG_NAME, 'h2').text
    # 방법 분류 가져오기 (list)
    method_category = driver.find_element(By.CLASS_NAME, 'name').find_element(By.TAG_NAME, 'a').text
    method_list = [method.strip() for method in method_category.split(',')]
    # 국가 분류 가져오기 (string)
    country = driver.find_element(By.XPATH, '/html/body/div/div[2]/div[2]/div[2]/dl[2]/dd/a').text
    # 테마 분류 가져오기 (list)
    theme_category = driver.find_element(By.CLASS_NAME, 'Theme').text
    theme_list = [theme.strip() for theme in theme_category.split(',')]
    # 칼로리 가져오기 (float)
    calorie = float(driver.find_element(By.XPATH, "/html/body/div/div[2]/div[2]/div[2]/dl[6]/dd/a").text.split('k')[0])
    # 조회수 가져오기 (int)
    view_text = driver.find_element(By.CLASS_NAME, 'visitor').find_element(By.TAG_NAME, 'strong').text
    view = int(view_text.replace('명', '').replace(',', ''))
    
    # 분량, 주재료 부재료 가져오기 (int, string, string)
    infoTable = driver.find_element(By.CSS_SELECTOR, "div.infoTable ul.tableLR")
    details = infoTable.find_elements(By.TAG_NAME, "li")
    amount_text = details[0].find_element(By.TAG_NAME, "dd").text
    amount = int(amount_text.split('인분')[0])
    main_ingredients = [ingredient.strip() for ingredient in details[1].find_element(By.TAG_NAME, "dd").text.split(',')]
    
    if len(details) > 2:  # 부재료가 있다고 가정
        sub_ingredients = [ingredient.strip() for ingredient in details[2].find_element(By.TAG_NAME, "dd").text.split(',')]
    else:
        sub_ingredients = "N/A"
    
    # 양념 섹션 체크 및 추출
    sauce = "N/A"
    if len(details) > 3:  # 양념 섹션이 있다고 가정
        sauce = [ingredient.strip() for ingredient in details[3].find_element(By.TAG_NAME, "dd").text.split(',')]

    # 레시피 가져오기
    recipe_steps = []
    steps_elements = driver.find_elements(By.CSS_SELECTOR, ".recipePlus dt")
    for step_element in steps_elements:
        step_text = step_element.text.strip()
        recipe_steps.append(step_text)

    menu = {
        '메뉴 이름': menu_name,
        '방법 분류': method_list,
        '국가 분류': country,
        '테마 분류': theme_list,
        '난이도 분류': '초보',
        '칼로리': calorie,
        '조회수': view,
        '분량': amount,
        '주재료 이름': main_ingredients,
        #'주재료 분량': ingredient_amounts,
        '부재료 이름': sub_ingredients,
        #'부재료 분량': sub_ingredient_amounts,
        '양념': sauce,
        '레시피': recipe_steps,
        '조리시간': beginner_df['cooking_time'][cooking_time_counter]
    }
    cooking_time_counter += 1
    data.append(menu)

    # 이미지 다운로드
    # Find image by tag and class if there are multiple img tags
    image_element = driver.find_element(By.CSS_SELECTOR, "img.img")
    img_url = image_element.get_attribute('src')
    response = requests.get(img_url)
    if response.status_code == 200:
        with open(f"{beginner_directory}/{menu_name}.jpg", 'wb') as f:
            f.write(response.content)
    else:
        print(f"Failed to download image for {menu_name}")


df = pd.DataFrame(data)
df.to_csv('beginner_recipe.csv', index=False, encoding='utf-8-sig')

# %%
recipe_urls = intermediate_df['url'].tolist()
data = []
cooking_time_counter = 0

for url in recipe_urls:
    driver.get(url)
    time.sleep(1)
    # 메뉴 이름 가져오기 (string)
    menu_name = driver.find_element(By.CLASS_NAME, 'wrap_top').find_element(By.TAG_NAME, 'h2').text
    # 방법 분류 가져오기 (list)
    method_category = driver.find_element(By.CLASS_NAME, 'name').find_element(By.TAG_NAME, 'a').text
    method_list = [method.strip() for method in method_category.split(',')]
    # 국가 분류 가져오기 (string)
    country = driver.find_element(By.XPATH, '/html/body/div/div[2]/div[2]/div[2]/dl[2]/dd/a').text
    # 테마 분류 가져오기 (list)
    theme_category = driver.find_element(By.CLASS_NAME, 'Theme').text
    theme_list = [theme.strip() for theme in theme_category.split(',')]
    # 칼로리 가져오기 (int)
    calorie = float(driver.find_element(By.XPATH, "/html/body/div/div[2]/div[2]/div[2]/dl[6]/dd/a").text.split('k')[0])
    # 조회수 가져오기 (int)
    view_text = driver.find_element(By.CLASS_NAME, 'visitor').find_element(By.TAG_NAME, 'strong').text
    view = int(view_text.replace('명', '').replace(',', ''))
    
    # 분량, 주재료 부재료 가져오기 (int, string, string)
    infoTable = driver.find_element(By.CSS_SELECTOR, "div.infoTable ul.tableLR")
    details = infoTable.find_elements(By.TAG_NAME, "li")
    amount_text = details[0].find_element(By.TAG_NAME, "dd").text
    amount = int(amount_text.split('인분')[0])
    main_ingredients = [ingredient.strip() for ingredient in details[1].find_element(By.TAG_NAME, "dd").text.split(',')]

    if len(details) > 2:  # 부재료가 있다고 가정
        sub_ingredients = [ingredient.strip() for ingredient in details[2].find_element(By.TAG_NAME, "dd").text.split(',')]
    else:
        sub_ingredients = "N/A"

    # 양념 섹션 체크 및 추출
    sauce = "N/A"
    if len(details) > 3:  # 양념 섹션이 있다고 가정
        sauce = [ingredient.strip() for ingredient in details[3].find_element(By.TAG_NAME, "dd").text.split(',')]

    # 레시피 가져오기
    recipe_steps = []
    steps_elements = driver.find_elements(By.CSS_SELECTOR, ".recipePlus dt")
    for step_element in steps_elements:
        step_text = step_element.text.strip()
        recipe_steps.append(step_text)

    menu = {
        '메뉴 이름': menu_name,
        '방법 분류': method_list,
        '국가 분류': country,
        '테마 분류': theme_list,
        '난이도 분류': '보통',
        '칼로리': calorie,
        '조회수': view,
        '분량': amount,
        '주재료 이름': main_ingredients,
        #'주재료 분량': ingredient_amounts,
        '부재료 이름': sub_ingredients,
        #'부재료 분량': sub_ingredient_amounts,
        '양념': sauce,
        '레시피': recipe_steps,
        '조리시간': beginner_df['cooking_time']
    }
    cooking_time_counter += 1
    data.append(menu)

    # 이미지 다운로드
    # Find image by tag and class if there are multiple img tags
    image_element = driver.find_element(By.CSS_SELECTOR, "img.img")
    img_url = image_element.get_attribute('src')
    response = requests.get(img_url)
    if response.status_code == 200:
        with open(f"{intermediate_directory}/{menu_name}.jpg", 'wb') as f:
            f.write(response.content)
    else:
        print(f"Failed to download image for {menu_name}")
    

df = pd.DataFrame(data)
df.to_csv('intermediate_recipe.csv', index=False, encoding='utf-8-sig')

# %% [markdown]
# # 이미지 누락 확인 (beginner_recipe.csv에서 메뉴 이름이 중복)

# %%
import pandas as pd

# Load the CSV file into a DataFrame
csv_file_path = 'beginner_recipe.csv'
df = pd.read_csv(csv_file_path)

# Find duplicates based on '메뉴 이름' or another suitable identifier
duplicates = df[df.duplicated('메뉴 이름', keep=False)]

# Print the duplicates to review them
print("Duplicate entries based on 메뉴 이름:")
print(duplicates)

# Alternatively, you can count the number of duplicates
duplicate_count = df.duplicated('메뉴 이름').sum()
print(f"There are {duplicate_count} duplicate entries based on 메뉴 이름.")
# Out:
# Duplicate entries based on 메뉴 이름:
#        메뉴 이름                방법 분류 국가 분류  \
# 37       참치죽     ['밥', '죽', '스프']    한식
# 38       참치죽     ['밥', '죽', '스프']    한식
# 99     알감자조림               ['조림']    한식
# 100    알감자조림               ['조림']    한식
# 120     두부김치               ['구이']    한식
# 213  해파리해물냉채  ['나물', '생채', '샐러드']    한식
# 214  해파리해물냉채  ['나물', '생채', '샐러드']    한식
# 266       화전          ['떡', '한과']    한식
# 267       화전          ['떡', '한과']    한식
# 332      대구전               ['부침']    한식
# 333      대구전               ['부침']    한식
# 369     두부김치               ['볶음']    한식
# 449    과일샐러드  ['나물', '생채', '샐러드']    서양
# 450    과일샐러드  ['나물', '생채', '샐러드']    서양
# 512    토마토소스              ['양념장']    서양
# 513    토마토소스              ['양념장']    서양
# 527     모양쿠키          ['빵', '과자']    서양
# 528     모양쿠키          ['빵', '과자']    서양
# 556    딸기스무디               ['음료']    서양
# 557    딸기스무디               ['음료']    서양
# 599     유부초밥     ['밥', '죽', '스프']    일본
# 600     유부초밥     ['밥', '죽', '스프']    일본
# 690    해물필라프     ['밥', '죽', '스프']  이탈리아
# 691    해물필라프     ['밥', '죽', '스프']  이탈리아
# 756   베이컨떡말이               ['조림']    퓨전
# 770   베이컨떡말이               ['구이']    퓨전
# 817    참치회무침  ['나물', '생채', '샐러드']    퓨전
# 818    참치회무침  ['나물', '생채', '샐러드']    퓨전
#
#                                            테마 분류 난이도 분류    칼로리     조회수  분량  \
# 37       ['일상식', '이유식', '아침식사', '어린이간식', '다이어트']     초보  260.0   65450   2
# 38               ['일상식', '이유식', '아침식사', '어린이간식']     초보  296.0   29059   2
# 99                        ['일상식', '아침식사', '도시락']     초보  127.0   98709   2
# 100                       ['일상식', '아침식사', '도시락']     초보  105.0   80422   4
# 120                                     ['소주술상']     초보  265.0   26328   2
# 213                                    ['어른생일상']     초보  112.0   39506   2
# 214                                     ['손님접대']     초보  112.0   42774   2
# 266           ['손님접대', '향토음식', '어른생일상', '어린이간식']     초보  200.0   29706   2
# 267                    ['손님접대', '어른생일상', '휴일요리']     초보  230.0   17654   2
# 332                     ['일상식', '향토음식', '어른생일상']     초보  166.0    6977   2
# 333                    ['손님접대', '향토음식', '어른생일상']     초보  166.0   30387   2
# 369       ['일상식', '바캉스식', '장마식', '맥주술상', '소주술상']     초보  253.0  147353   4
# 449      ['채식', '맥주술상', '아침식사', '어린이간식', '다이어트']     초보  171.0  147950   2
# 450  ['손님접대', '연인식', '크리스마스', '발렌타인데이', '어린이간식']     초보  146.0   32697   2
# 512                                         ['']     초보   78.0   15174   4
# 513          ['손님접대', '어린이생일상', '어린이간식', '휴일요리']     초보   78.0   19221   4
# 527                          ['어린이생일상', '어린이간식']     초보  344.0   35872   2
# 528                                    ['어린이간식']     초보  158.0   57984   2
# 556                                    ['어린이간식']     초보  185.0   47079   2
# 557                            ['아침식사', '어린이간식']     초보  180.0    5262   2
# 599           ['어린이생일상', '아침식사', '어린이간식', '도시락']     초보  340.0   58237   2
# 600           ['바캉스식', '어른생일상', '어린이생일상', '도시락']     초보  195.0   27800   2
# 690                                     ['손님접대']     초보  398.0   34044   2
# 691                             ['손님접대', '휴일요리']     초보  452.0   28798   2
# 756                     ['맥주술상', '어린이간식', '집들이']     초보  210.0   38284   2
# 770                  ['어린이생일상', '어린이간식', '휴일요리']     초보  120.0   31641   2
# 817                                     ['다이어트']     초보  132.0   34133   2
# 818                             ['맥주술상', '소주술상']     초보  118.0   22539   2
#
#                                                주재료 이름  \
# 37                                ['밥 2공기', '참치캔 1개']
# 38                             ['참치통조림 1캔', '불린쌀 1컵']
# 99                                        ['알감자 60g']
# 100                                      ['알감자 300g']
# 120                            ['두부 1/2모', '신김치 50g']
# 213                   ['해파리 80g', '새우 6개', '쭈꾸미 20g']
# 214                   ['해파리 80g', '새우 4개', '쭈구미 20g']
# 266                                     ['찹쌀가루 160g']
# 267                                     ['찹쌀가루 160g']
# 332                                      ['대구살 200g']
# 333                                   ['대구(냉동) 400g']
# 369                           ['두부 1모', '배추김치 1/2포기']
# 449    ['사과 1개', '자몽 1개', '샐러리 1대', '오이 1개', '딸기 4개']
# 450  ['방울토마토 8개', '키위 2개', '파인애플통조림 4조각', '과일통조림 약간']
# 512                           ['홀토마토 1/2캔', '토마토 1개']
# 513                           ['홀토마토 1/2캔', '토마토 1개']
# 527                                        ['박력분 2컵']
# 528                                      ['박력분 700g']
# 556                    ['딸기(냉동딸기) 200g', '요구르트 200g']
# 557                            ['딸기 100g', '레몬 1/2개']
# 599                                ['유부 6개', '밥 1공기']
# 600         ['밥 1공기', '유부 1봉지', '쪽파 1/2뿌리', '검은깨 약간']
# 690  ['쌀 1컵', '오징어 1마리', '새우 3마리', '고동 1개', '바지락 5개']
# 691                     ['쌀 2컵', '오징어 1마리', '새우 5마리']
# 756                              ['가래떡 2개', '베이컨 8장']
# 770                                        ['가래떡 2줄']
# 817                                      ['참치회 300g']
# 818                                      ['참치회 300g']
#
#                                                 부재료 이름  \
# 37                                         ['대파 1/3개']
# 38   ['당근 1/3개', '감자 1개', '표고버섯 2장', '실파 2줄기', '물 5...
# 99                                           ['소금 약간']
# 100                                           ['물 1컵']
# 120                               ['햄 200g', '식용유 약간']
# 213        ['오이 1/3개', '당근 1/4개', '홍피망 1/2개', '계란 1개']
# 214           ['오이 20g', '당근 20g', '홍피망 15g', '계란 1개']
# 266              ['물 5큰술', '대추 6알', '쑥갓 5잎', '식용유 약간']
# 267                      ['대추 2알', '쑥갓 약간', '식용유 적당량']
# 332            ['계란 1개', '밀가루 2큰술', '쑥갓 약간', '식용유 약간']
# 333                 ['밀가루 1/2컵', '계란 2개', '올리브오일 적당량']
# 369                              ['깻잎 10장', '깨소금 1큰술']
# 449                                    ['오렌지마요네즈 4큰술']
# 450                                        ['씨리얼 2큰술']
# 512  ['양파 1/4개', '당근 1/8개', '샐러리 1/4대', '월계수잎 1장', ...
# 513  ['양파 1/4개', '당근 1/8개', '샐러리 1/4대', '월계수잎 1장', ...
# 527  ['베이킹파우더 2작은술', '버터(마가린) 60g', '설탕 2/3컵', '계란 ...
# 528  ['설탕 225g', '베이킹파우더 3g', '우유 200g', '버터 135g',...
# 556          ['레몬즙 1작은술', '시럽 40g', '설탕 20g', '물 20g']
# 557                           ['플레인요구르트 2큰술', '꿀 2큰술']
# 599  ['당근 10g', '우엉 10g', '단무지 5g', '계란 1개', '흑임자 약간']
# 600                   ['베이컨 3개', '양파 1/2개', '당근 1/2개']
# 690                                        ['스위ㅡ콘 1캔']
# 691            ['물 2컵', '고동 20g', '스위트콘 약간', '조개 20g']
# 756  ['간장 4큰술', '물엿 1큰술', '조미술 2큰술', '흰후춧가루 약간', '물...
# 770                                         ['베이컨 8장']
# 817  ['적채 50g', '청고추 2개', '홍고추 2개', '치커리 30g', '깻잎 ...
# 818  ['오이 150g', '사과 150g', '양상추 100g', '쑥갓 100g', ...
#
#                                                     양념  \
# 37                                          ['참기름 약간']
# 38                      ['참기름 약간', '국간장 약간', '깨소금 약간']
# 99   ['간장 3큰술', '물엿 1큰술', '설탕 1/2큰술', '미림 1/4큰술', '...
# 100  ['간장 2큰술', '물엿 1큰술', '설탕 1작은술', '참기름 약간', '깨소금...
# 120                                ['소금 약간', '참기름 약간']
# 213  ['겨자 2큰술', '머스터드 1/2큰술', '마늘 2쪽', '식초 3큰술', '설...
# 214  ['겨자 2큰술', '머스터드 1/2큰술', '마늘 약간', '식초 3큰술', '설...
# 266                                ['설탕 3큰술', '물 3큰술']
# 267                       ['소금 약간', '설탕 3큰술', '물 3큰술']
# 332                               ['소금 약간', '후춧가루 약간']
# 333                               ['소금 약간', '후춧가루 약간']
# 369      ['다진파 1큰술', '다진마늘 1/2큰술', '참기름 1큰술', '소금 약간']
# 449                                                NaN
# 450                                      ['시판용드레싱 약간']
# 512            ['소금 약간', '후춧가루 약간', '바질 약간', '통후추 약간']
# 513                                                NaN
# 527                                                NaN
# 528                                                NaN
# 556                                                NaN
# 557                                                NaN
# 599  ['식초 1과1/2큰술', '설탕 2/3큰술', '소금 1/4큰술', '간장 1큰술...
# 600  ['소금 약간', '간장 2큰술', '설탕 1큰술', '맛술 1큰술', '다시물 1...
# 690           ['물 1컵', '카레가루 4큰술', '소금 약간', '후춧가루 약간']
# 691                    ['카레가루 3큰술', '소금 약간', '통후추 약간']
# 756                                                NaN
# 770  ['간장 4큰술', '올리고당 1큰술', '흰후춧가루 약간', '돌나물 1/2컵',...
# 817                    ['고추장 1큰술', '식초 1큰술', '설탕 1큰술']
# 818  ['고추장 1/2컵', '고추냉이 2작은술', '깨소금 2큰술', '설탕 2큰술',...
#
#                                                    레시피  조리시간
# 37   ['1. 참치캔의 기름은 체에 밭쳐 제거하고 찬밥, 물과 함께 집어넣고 푹 끓인다....    30
# 38   ['1. 참치통조림은 체에 밭쳐 기름기를 제거한다.', '2. 당근, 감자, 표고버...    30
# 99   ['1. 알감자의 껍질을 깨끗하게 씻는다.', '2. 씻어낸 알감자를 소금 넣은 물...    30
# 100  ['1. 알감자의 껍질을 깨끗이 씻는다.', '2. 씻어낸 알감자는 소금을 약간 넣...    30
# 120  ['1. 두부는 1~2cm 두깨로 썰어 소금을 넣은 물에 살짝 데쳐 물기를 빼준다....    30
# 213  ['1. 해파리는 먼저 옅은 소금물에 10분간 담그고 끓는물에 데친다.', '2. ...    60
# 214  ['1. 해파리는 먼저 옅은 소금물에 10분간 담그고 끓는 물에 데친다.', '2....    30
# 266  ['1. 찹쌀가루를 익반죽하여 오랫동안 치댄다.', '2. 쑥갓은 찬물에 담갔다가 ...    30
# 267  ['1. 찹쌀가루를 익반죽하여 오랫동안 치댄다.', '2. 쑥갓은 찬물에 담갔다가 ...    30
# 332  ['1. 대구살을 전으로 부치기 쉽도록 포를 뜬다.', '2. 생선의 물기를 제거한...    30
# 333  ['1. 얇게 포 뜬 냉동대구는 해동하여 물기를 제거하고 소금과 후춧가루를 적당히 ...    30
# 369  ['1. 두부는 팔팔 끓는물에 소금을 약간 넣고 속까지 따뜻하게 익도록 데쳐낸다.'...    20
# 449  ['1. 사과는 깨끗이 씻어서 길이로 반을 자른 후 씨를 도려낸다. 길이 4cm, ...    20
# 450  ['1. 방울토마토는 흐르는 물에 헹궈 물기를 빼준다.', '2. 키위는 껍질을 벗...    20
# 512  ['1. 토마토 과육은 손으로 으깨어 놓고 토마토 과즙은 그대로 준비한다.', '2...    30
# 513  ['1. 홀토마토는 캔에서 꺼내어 체에 밭쳐 토마토 과육은 손으로 으깨어놓고 토마토...    60
# 527  ['1. 박력분과 베이킹 파우더를 섞어 고운 체에 내려 준비한다.', '2. 오목한...    30
# 528  ['1. 마가린, 쇼트닝, 설탕을 섞어 설탕이 녹을때까지 손으로 주무르고 돌리면서 ...    60
# 556  ['1. 설탕 20g과 물 20g을 섞은 뒤 설탕이 녹을 정도로만 살짝 끓여 차갑게...    10
# 557  ['1. 딸기는 흐르는 물에 깨끗이 씻어 꼭지를 떼내고 물기를 빼둔다.', '2. ...    10
# 599  ['1. 조미된 유부를 구입하여 대각선으로 반 갈라놓는다.', '2 당근, 우엉, ...    30
# 600  ['1. 당근, 양파, 쪽파, 베이컨은 잘게 다져 준비한다.', '2. 팬에 ①번 ...    30
# 690  ['1. 스위트콘을 체에 밭쳐 물기를 빼 놓는다.', '2. 오징어는 깨끗이 손질하...    60
# 691  ['1. 스위트콘을 체에 받쳐 물기를 빼 놓는다.', '2. 오징어는 깨끗이 손질하...    60
# 756  ['1. 가래떡은 4cm 길이로 썰어 미지근한 물에 넣어 부드럽게 만든다.', '2...    30
# 770  ['1. 가래떡은 4cm 길이로 썰어 미지근한 물에 불려 부드럽게 만든다.', '2...    60
# 817  ['1. 냉동참치는 소금물에 10분쯤 담가 두었다가 물기를 걷고 냉장고에 넣어둔다....    20
# 818  ['1. 냉동참치는 횟감으로 준비하여 미지근한 소금물에 잠시 담근 후 먹기좋은 크기...    15
# There are 14 duplicate entries based on 메뉴 이름.
